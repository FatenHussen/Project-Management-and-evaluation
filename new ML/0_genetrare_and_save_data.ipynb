# %% [markdown]
# ### genertae dataset and save it in datafrmae in excel file

# %%
import pandas as pd
import numpy as np
import random

# %%
# Define the dimensions of the dataset
num_rows = 2500
num_features = 9
min_values_per_feature = 5
max_values_per_feature = 16
columns=["مرجعية","تحليل","صميم", "برمجة","اختبار","نتائج","تقرير","عرض","غيتهاب"]

# %%
# Create an empty dataset
dataset1 = []
num_rows1=650
# Generate random data for the dataset with values between 0 and 50
for _ in range(num_rows1):
    row = []
    num_values = random.randint(min_values_per_feature, max_values_per_feature)
    for _ in range(num_features):
        values = [random.randint(10, 51) for _ in range(num_values)]
        row.append(values)
    dataset1.append(row)

# %%
# Generate random data for the dataset with values between 70 and 100
dataset2 = []
num_rows2=650
for _ in range(num_rows2):
    row = []
    num_values = random.randint(min_values_per_feature, max_values_per_feature)
    for _ in range(num_features):
        values = [random.randint(70, 101) for _ in range(num_values)]
        row.append(values)
    dataset2.append(row)

# %%
# Generate random data for the dataset with values between 50 and 70
dataset3 = []
num_rows3=1200
for _ in range(num_rows3):
    num_values = random.randint(min_values_per_feature, max_values_per_feature)
    row = []
    for _ in range(num_features):
        values = [random.randint(20, 90) for _ in range(num_values)]
        row.append(values)
    dataset3.append(row)

# %%
dataset= dataset1 + dataset2 + dataset3

# Convert the dataset to a DataFrame
df = pd.DataFrame(dataset, columns=["مرجعية","تحليل","تصميم", "برمجة","اختبار","نتائج","تقرير","عرض","غيتهاب"])
# save data en excel file
df.to_excel('data_for_classification.xlsx', index=False)
print("Original DataFrame:")
df
# Out:
# Original DataFrame:
#                                                  مرجعية  \
# 0              [43, 31, 39, 46, 42, 42, 25, 37, 38, 24]
# 1     [24, 19, 18, 33, 51, 35, 27, 49, 47, 29, 50, 2...
# 2              [41, 34, 37, 10, 12, 10, 18, 27, 19, 21]
# 3     [42, 35, 37, 34, 51, 43, 30, 27, 35, 48, 39, 3...
# 4                                  [48, 47, 32, 45, 31]
# ...                                                 ...
# 2495           [34, 46, 21, 44, 32, 65, 66, 59, 45, 44]
# 2496                   [49, 48, 66, 87, 89, 80, 70, 25]
# 2497               [84, 90, 36, 75, 62, 58, 59, 31, 65]
# 2498                           [26, 48, 54, 24, 74, 83]
# 2499  [84, 34, 26, 77, 20, 33, 83, 79, 84, 29, 52, 5...
#
#                                                   تحليل  \
# 0              [43, 23, 27, 23, 28, 38, 11, 30, 42, 33]
# 1     [50, 20, 27, 42, 44, 30, 39, 23, 39, 19, 33, 4...
# 2              [20, 12, 47, 27, 50, 25, 35, 24, 48, 10]
# 3     [35, 16, 38, 19, 28, 45, 37, 50, 37, 33, 40, 5...
# 4                                  [23, 11, 51, 37, 14]
# ...                                                 ...
# 2495           [53, 85, 29, 50, 34, 47, 67, 27, 66, 25]
# 2496                   [57, 79, 32, 39, 45, 70, 70, 23]
# 2497               [43, 67, 84, 90, 72, 28, 70, 69, 36]
# 2498                           [56, 33, 82, 65, 63, 48]
# 2499  [21, 77, 65, 63, 69, 67, 52, 58, 43, 71, 32, 8...
#
#                                                   تصميم  \
# 0              [29, 13, 42, 39, 49, 43, 27, 40, 19, 30]
# 1     [48, 12, 12, 26, 34, 35, 22, 15, 36, 14, 51, 2...
# 2              [43, 22, 40, 33, 45, 50, 18, 11, 49, 23]
# 3     [16, 16, 49, 21, 26, 37, 18, 26, 29, 21, 32, 3...
# 4                                  [27, 32, 13, 34, 19]
# ...                                                 ...
# 2495           [74, 48, 68, 36, 73, 74, 38, 54, 60, 28]
# 2496                   [75, 43, 83, 74, 72, 78, 62, 38]
# 2497               [30, 28, 76, 32, 73, 67, 84, 49, 65]
# 2498                           [72, 26, 27, 53, 74, 74]
# 2499  [70, 65, 42, 22, 49, 35, 85, 21, 43, 67, 39, 4...
#
#                                                   برمجة  \
# 0              [48, 29, 28, 45, 11, 16, 13, 14, 16, 18]
# 1     [21, 38, 49, 37, 51, 12, 10, 20, 43, 11, 19, 2...
# 2              [18, 27, 29, 24, 10, 22, 47, 40, 23, 31]
# 3     [12, 32, 46, 26, 19, 17, 20, 25, 19, 41, 11, 2...
# 4                                  [27, 12, 36, 24, 28]
# ...                                                 ...
# 2495           [88, 87, 84, 79, 65, 24, 88, 51, 80, 47]
# 2496                   [58, 58, 89, 80, 57, 55, 48, 54]
# 2497               [27, 20, 59, 46, 46, 60, 68, 73, 30]
# 2498                           [68, 47, 31, 79, 76, 82]
# 2499  [40, 71, 38, 33, 77, 56, 63, 45, 41, 69, 22, 5...
#
#                                                  اختبار  \
# 0              [11, 28, 20, 10, 15, 25, 34, 32, 37, 35]
# 1     [16, 16, 43, 30, 10, 22, 41, 36, 13, 34, 32, 4...
# 2              [10, 10, 41, 26, 34, 34, 35, 15, 22, 37]
# 3     [10, 48, 24, 33, 47, 46, 24, 45, 44, 14, 36, 3...
# 4                                  [38, 30, 36, 13, 32]
# ...                                                 ...
# 2495           [84, 68, 80, 89, 32, 57, 43, 48, 20, 87]
# 2496                   [41, 49, 20, 69, 56, 72, 86, 81]
# 2497               [63, 30, 84, 21, 25, 61, 25, 72, 87]
# 2498                           [71, 28, 30, 85, 65, 70]
# 2499  [43, 52, 90, 35, 62, 50, 43, 24, 42, 62, 54, 3...
#
#                                                   نتائج  \
# 0              [19, 50, 37, 33, 23, 49, 22, 29, 25, 34]
# 1     [34, 11, 14, 26, 29, 26, 19, 33, 36, 27, 51, 4...
# 2              [19, 19, 21, 26, 26, 27, 45, 45, 35, 29]
# 3     [19, 48, 34, 17, 28, 29, 18, 46, 29, 15, 22, 3...
# 4                                  [18, 15, 22, 48, 48]
# ...                                                 ...
# 2495           [81, 59, 60, 75, 37, 38, 50, 64, 77, 49]
# 2496                   [30, 63, 79, 48, 55, 63, 67, 45]
# 2497               [41, 64, 36, 76, 36, 27, 39, 21, 39]
# 2498                           [49, 76, 78, 37, 25, 42]
# 2499  [79, 88, 45, 28, 48, 88, 72, 88, 65, 27, 24, 5...
#
#                                                   تقرير  \
# 0              [34, 43, 20, 45, 30, 29, 23, 31, 12, 38]
# 1     [22, 49, 31, 16, 18, 48, 11, 38, 24, 49, 40, 1...
# 2              [18, 12, 30, 28, 46, 17, 23, 50, 45, 24]
# 3     [33, 41, 44, 12, 34, 10, 17, 51, 36, 41, 36, 3...
# 4                                  [18, 23, 39, 16, 20]
# ...                                                 ...
# 2495           [41, 63, 69, 68, 68, 43, 40, 71, 34, 60]
# 2496                   [82, 30, 75, 41, 88, 76, 35, 48]
# 2497               [51, 39, 31, 56, 73, 48, 49, 65, 59]
# 2498                           [59, 52, 48, 38, 31, 69]
# 2499  [36, 63, 30, 63, 46, 25, 55, 67, 25, 47, 39, 6...
#
#                                                     عرض  \
# 0              [30, 13, 19, 29, 15, 34, 12, 22, 28, 26]
# 1     [42, 13, 45, 39, 25, 10, 27, 18, 27, 44, 11, 3...
# 2              [23, 21, 22, 34, 10, 38, 42, 37, 39, 21]
# 3     [35, 50, 38, 27, 19, 25, 14, 47, 40, 40, 50, 4...
# 4                                  [22, 14, 48, 15, 16]
# ...                                                 ...
# 2495           [78, 21, 87, 76, 32, 52, 77, 86, 36, 82]
# 2496                   [31, 76, 46, 65, 66, 72, 45, 54]
# 2497               [44, 30, 26, 61, 77, 90, 83, 55, 82]
# 2498                           [82, 47, 32, 33, 86, 57]
# 2499  [23, 40, 34, 50, 71, 85, 89, 52, 46, 51, 33, 7...
#
#                                                  غيتهاب
# 0              [21, 16, 41, 16, 34, 49, 24, 51, 51, 17]
# 1     [26, 16, 51, 40, 14, 38, 11, 42, 23, 17, 44, 2...
# 2              [49, 29, 48, 31, 45, 29, 15, 28, 49, 18]
# 3     [14, 25, 36, 44, 32, 50, 14, 31, 21, 41, 17, 3...
# 4                                  [36, 19, 27, 43, 38]
# ...                                                 ...
# 2495           [56, 56, 46, 36, 41, 62, 23, 58, 42, 57]
# 2496                   [90, 28, 64, 87, 90, 34, 44, 45]
# 2497               [54, 64, 23, 40, 47, 44, 72, 28, 44]
# 2498                           [62, 53, 78, 23, 43, 81]
# 2499  [62, 46, 43, 60, 34, 84, 69, 75, 65, 68, 76, 2...
#
# [2500 rows x 9 columns]
